# %% [markdown]
# # Lab 06 — Transfer Learning with ResNet-50 on Tiny-ImageNet
#
# **Runtime:** `Runtime > Change runtime type > T4 GPU`

# %%
import torch

assert torch.cuda.is_available(), "GPU not available. Go to Runtime > Change runtime type > T4 GPU."
print(f"GPU: {torch.cuda.get_device_name(0)}")
print(f"PyTorch: {torch.__version__}")
# Out:
# GPU: Tesla T4
# PyTorch: 2.10.0+cu128

# %%
import os

os.chdir("/content")
assert os.path.exists("train.py"), f"train.py not found in {os.getcwd()}"
print(f"Working directory: {os.getcwd()}")
# Out:
# Working directory: /content

# %%
# %pip install -q wandb datasets pyyaml python-dotenv

# %%
import os
import wandb
from dotenv import load_dotenv

# .env 파일을 /content/ 에 업로드한 뒤 실행하세요
# 파일 내용 예시:  WANDB_API_KEY=your_key_here
load_dotenv("/content/.env")

WANDB_API_KEY = os.environ.get("WANDB_API_KEY", "")
if not WANDB_API_KEY:
    raise ValueError(".env 파일에 WANDB_API_KEY가 설정되어 있지 않습니다.")

wandb.login(key=WANDB_API_KEY)
wandb.init(entity="finemini2001-sungkyunkwan-university", project="osai-lab06")

# %%
# %run train.py
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">soft-planet-15</strong> at: <a href='https://wandb.ai/finemini2001-sungkyunkwan-university/osai-lab06/runs/l7bwuydy' target="_blank">https://wandb.ai/finemini2001-sungkyunkwan-university/osai-lab06/runs/l7bwuydy</a><br> View project at: <a href='https://wandb.ai/finemini2001-sungkyunkwan-university/osai-lab06' target="_blank">https://wandb.ai/finemini2001-sungkyunkwan-university/osai-lab06</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260412_103508-l7bwuydy/logs</code>
# Tracking run with wandb version 0.25.1
# Run data is saved locally in <code>/content/wandb/run-20260412_103532-eiiarm0d</code>
# ...

# %%
# Optional: evaluate the best checkpoint
# %run eval.py
# Out:
# === Parameter Counts ===
#   total                              :   11,563,850
#   trainable                          :    3,020,554
#   layer/backbone                     :    8,543,296
#   layer/extra_layers                 :    2,886,656
#   layer/classifier                   :      133,898
# === Evaluation Results ===
#   Loss : 0.1655
#   Top-1: 97.86%
